# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2']  #this is the way of caling column
# Out:
# 0    444
# 1    555
# 2    666
# 3    444
# Name: col2, dtype: int64

# %%
df['col2'].unique() #it is the way you can call unique values
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()  #its gives you number of unique values
# Out:
# 3

# %% [markdown]
# Applying Function

# %%
def times2(x):
  return x*2

# %%
df['col1'].apply(times2)  #applying function on column 1
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col1']  #but function isn't update the column
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col1'].sum()  #sum the column value
# Out:
# 10

# %%
# Permanantly removing column
#del df['col1']

# %%
df.columns  #it will give you columns name
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.sort_values(by='col2') #sort the intire table but according to col2 but it's can't update table
#df.sort_values(by='col2', inplace=True) it will update the table
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
# df.sort_values(by='col2', inplace=True) #if you want to update the table
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df2=df.sort_values(by='col2')

df2
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull() #it's checking missing value and if its there it will give you true
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
df.dropna() #drop rows with NaN values
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df3 = pd.DataFrame({'col1':[1,2,3,np.nan],'col2':[np.nan,555,666,444],'col3':['abc','def','ghi','xyz']})
df3
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df3.fillna('FILL')  #it update the value of NAN to FILL
# Out:
#    col1   col2 col3
# 0   1.0   FILL  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3  FILL  444.0  xyz

# %% [markdown]
# **CSV**

# %%
#Upload file directly from files option and then use this command to open this csv file
df4=pd.read_csv('/content/Salaries (3).csv')
df4.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
df4.tail(10)  #it will give you the bottom values
# Out:
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# ...

# %%
df4.info()  #info about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
df4.describe()  #statistical information
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
df4['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
df4['BasePay'].max()
# Out:
# 319275.01

# %%
df4['OvertimePay'].max()
# Out:
# 245131.88

# %%
df4.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df4[df4['EmployeeName']=='ALSON LEE']
# Out:
#    Id EmployeeName                            JobTitle   BasePay  OvertimePay  \
# 6   7    ALSON LEE  BATTALION CHIEF, (FIRE DEPARTMENT)  92492.01      89062.9
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 6  134426.14       NaN  315981.05         315981.05  2011    NaN
#
#           Agency  Status
# 6  San Francisco     NaN

# %%
df4[df4['EmployeeName']=="ALSON LEE"]['JobTitle'] #index on the job title of selected person
# Out:
# 6    BATTALION CHIEF, (FIRE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
df4[df4['EmployeeName']=="JOSEPH DRISCOLL"]['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
df4[df4['EmployeeName']=="ALSON LEE"]['TotalPayBenefits']
# Out:
# 6    315981.05
# Name: TotalPayBenefits, dtype: float64

# %%
df4[df4['TotalPayBenefits'].max()]["EmployeeName"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 567595.43
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-f35bf2676279> in <cell line: 1>()
# ----> 1 df4[df4['TotalPayBenefits'].max()]["EmployeeName"]
#
# ...

# %%
df4['TotalPayBenefits'].max()
# Out:
# 567595.43

# %%
df4[df4['TotalPayBenefits']==df4['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
df4.loc['id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-6c94eb9e8353> in <cell line: 1>()
# ----> 1 df4.loc['id']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#    1432
#    1433     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# ...

# %%
df4.iloc[0:4,:]  #slicing row and column [row start:end,column start:end] for matrix we dont use iloc for dataframe we use iloc
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN

# %%
df4.iloc[0:4,0:13:2]
# Out:
#    Id                                        JobTitle  OvertimePay  Benefits  \
# 0   1  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY         0.00       NaN
# 1   2                 CAPTAIN III (POLICE DEPARTMENT)    245131.88       NaN
# 2   3                 CAPTAIN III (POLICE DEPARTMENT)    106088.18       NaN
# 3   4            WIRE ROPE CABLE MAINTENANCE MECHANIC     56120.71       NaN
#
#    TotalPayBenefits  Notes  Status
# 0         567595.43    NaN     NaN
# 1         538909.28    NaN     NaN
# 2         335279.91    NaN     NaN
# 3         332343.61    NaN     NaN

# %%
type(df4.iloc[0:4,0:13:2])
# Out:
# pandas.core.frame.DataFrame

# %%
df4.iloc[0:4,0:13:2].values #this is numpy array
# Out:
# array([[1, 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 0.0, nan,
#         567595.43, nan, nan],
#        [2, 'CAPTAIN III (POLICE DEPARTMENT)', 245131.88, nan, 538909.28,
#         nan, nan],
#        [3, 'CAPTAIN III (POLICE DEPARTMENT)', 106088.18, nan, 335279.91,
#         nan, nan],
#        [4, 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 56120.71, nan,
#         332343.61, nan, nan]], dtype=object)
